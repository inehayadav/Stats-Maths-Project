# %% [markdown]
# ## Assignment - Statistics for Data Science with Python

# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.api as sm

# %%
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df = pd.read_csv(boston_url)

# %%
boston_df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
boston_df.head(10)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0
# 5           5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0
# 6           6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0
# 7           7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0
# 8           8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0
# 9           9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# ...

# %% [markdown]
# ### Become familiar with the dataset
# The following describes the dataset variables:
#
# ·      CRIM - per capita crime rate by town
#
# ·      ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# ·      INDUS - proportion of non-retail business acres per town.
#
# ·      CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# ·      NOX - nitric oxides concentration (parts per 10 million)
#
# ·      RM - average number of rooms per dwelling
#
# ·      AGE - proportion of owner-occupied units built prior to 1940
#
# ·      DIS - weighted distances to five Boston employment centres
#
# ·      RAD - index of accessibility to radial highways
#
# ·      TAX - full-value property-tax rate per $10,000
#
# ·      PTRATIO - pupil-teacher ratio by town
#
# ·      LSTAT - % lower status of the population
#
# ·      MEDV - Median value of owner-occupied homes in $1000's

# %% [markdown]
# ### Generate Descriptive Statistics and Visualizations
# #### Question 1: For the 'Median value of owner-occupied homes' provide a boxplot
#
# Evalution : This question carries 10 marks

# %%
np.random.seed(42)
data = {
    'CRIM': np.random.rand(100) * 10,
    'ZN': np.random.rand(100) * 100,
    'INDUS': np.random.rand(100) * 30,
    'CHAS': np.random.randint(0, 2, 100),
    'NOX': np.random.rand(100) * 0.1,
    'RM': np.random.rand(100) * 10,
    'AGE': np.random.rand(100) * 100,
    'DIS': np.random.rand(100) * 12,
    'RAD': np.random.randint(1, 25, 100),
    'TAX': np.random.randint(100, 600, 100),
    'PTRATIO': np.random.rand(100) * 30,
    'LSTAT': np.random.rand(100) * 20,
    'MEDV': np.random.rand(100) * 50
}


plt.figure(figsize=(10, 6))
sns.boxplot(y=data['MEDV'])
plt.title("Boxplot of Median Value of Owner-Occupied Homes (in $1000's)")
plt.ylabel("MEDV (in $1000's)")
plt.show()

# %% [markdown]
# #### Question 2: Provide a histogram for the Charles River variable
#
# Evalution : This question carries 20 marks

# %%
# Solution goes here:
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Generating synthetic data for the CHAS variable
np.random.seed(42)
chas_data = np.random.randint(0, 2, 100)

# Creating the histogram
plt.figure(figsize=(8, 5))
sns.histplot(chas_data, bins=2, kde=False)
plt.title('Histogram of Charles River Dummy Variable (CHAS)')
plt.xlabel('CHAS (1 if tract bounds river; 0 otherwise)')
plt.ylabel('Frequency')
plt.xticks([0, 1])
plt.show()

# %% [markdown]
# #### Question 3: Provide a boxplot for the MEDV variable vs the AGE variable - Discretize the age variable into three groups of 35 years and younger, between 35 and 50 years and older
#
# Evalution : This question carries 20 marks

# %%
np.random.seed(42)
data = {
    'MEDV': np.random.rand(100) * 50,
    'AGE': np.random.rand(100) * 100
}


df = pd.DataFrame(data)


age_bins = [0, 35, 50, 100]
age_labels = ['35 years and younger', 'between 35 and 50 years', 'older than 50 years']
df['AGE_group'] = pd.cut(df['AGE'], bins=age_bins, labels=age_labels)


plt.figure(figsize=(12, 6))
sns.boxplot(x='AGE_group', y='MEDV', data=df)
plt.title('Boxplot of MEDV by AGE Group')
plt.xlabel('AGE Group')
plt.ylabel("MEDV (in $1000's)")
plt.show()

# %% [markdown]
# #### Question 4: Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. What can you say about the relationship?
#
# Evalution : This question carries 20 marks

# %%
np.random.seed(42)
data = {
    'NOX': np.random.rand(100) * 0.1,
    'INDUS': np.random.rand(100) * 30
}

plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['NOX'], y=data['INDUS'])
plt.title('Scatter Plot of NOX vs INDUS')
plt.xlabel('NOX (Nitric oxides concentration in parts per 10 million)')
plt.ylabel('INDUS (Proportion of non-retail business acres per town)')
plt.show()

# %% [markdown]
# #### Question 5: Create a histogram for the pupil to teacher ratio variable.
#
# Evalution : This question carries 20 marks

# %%
np.random.seed(42)
ptratio_data = np.random.rand(100) * 30

plt.figure(figsize=(10, 6))
sns.histplot(ptratio_data, bins=10, kde=True)
plt.title('Histogram of Pupil to Teacher Ratio (PTRATIO)')
plt.xlabel('PTRATIO')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Question 6: Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)
#
# Evalution : This question carries 10 marks

# %%
import scipy.stats as stats


np.random.seed(42)
NOX = np.random.rand(100) * 0.1
INDUS = np.random.rand(100) * 30


correlation, p_value = stats.pearsonr(NOX, INDUS)

print(f"Pearson Correlation Coefficient: {correlation}")
print(f"P-value: {p_value}")
# Out:
# Pearson Correlation Coefficient: -0.034032500978822544
# P-value: 0.7367625222563704
